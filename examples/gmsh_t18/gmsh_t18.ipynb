# %% [markdown]
# # Gmsh Python tutorial 18

# %% [markdown]
# ![](<https://gmsh.info/doc/texinfo/images/t18.png>)

# %%
import os
import subprocess

import numpy as np
import pandas as pd
import pyvista as pv
import plotly as plt
import sgio

pv.set_jupyter_backend('trame')

# %%
from build_sg import build_sg
from convert import convert_sg
# from run_sc import run_sc

working_dir = 'evals'

# Run SG analysis for a range of radii
radii = np.linspace(0.1, 0.4, 7)
print(f'{radii=}')

out = []

for i, radius in enumerate(radii):
    print(f'Running for radius: {radius}')

    _out = {
        'radius': radius
    }

    # Create working directory if it doesn't exist
    wd = os.path.join(working_dir, f'eval.{i}')
    if not os.path.exists(wd):
        os.makedirs(wd)

    fn_sg_base = os.path.join(wd, 'sg')
    build_sg(radius=radius, fn_sg_base=fn_sg_base, mesh_size=0.05, nopopup=True)

    fn_sg_sc = f'{fn_sg_base}.sg'
    _out['fn_sg_sc'] = fn_sg_sc
    convert_sg(fn_sg_in=f'{fn_sg_base}.msh', fn_sg_out=fn_sg_sc)

    # sc_cmd = os.path.join()
    cp = subprocess.run(
        ["C:\Program Files\AnalySwift\SwiftComp.exe", fn_sg_sc, '3D', 'H'],
        capture_output=True
        )

    # print(cp.stdout.decode())
    # print(cp.stderr.decode())

    sc_out = sgio.readOutputModel(f'{fn_sg_sc}.k', file_format='sc', model_type='sd1')
    _out['property'] = sc_out.model_dump(exclude_none=True)

    out.append(_out)
# Out:
# radii=array([0.1, 0.2, 0.3, 0.4])
# Running for radius: 0.1
# matrix_volumes=[17]
# inclusion_volumes=[19, 21, 18, 20]
#  ****************************************************************
#  *                      SwiftComp  2.1                          *
#  *                                                              *
#  *         Multiscale Constitutive Modeling of Composites       *
#  *                                                              *
#  *            School of Aeronautics and Astronautics            *
#  *                       Purdue University                      *
#  *                                                              *
#  *                       Copyright Notice                       *
#  *                     ====================                     *
#  *                                                              *
#  * Copyright (2015-) by Purdue Research Foundation, West        *
#  * Lafayette, IN  47906.  Unless permission is granted, this    *
#  * material may not be copied, reproduced or coded for          *
#  * reproduction by any electrical, mechanical or chemical       *
#  * process or combination thereof, now known or later developed.*
#  *                                                              *
#  * These commodities, technology or software were exported from *
#  * the United States in accordance with the Export              *
#  * Administration Regulations. Diversion contrary to U.S. law   *
#  * prohibited.                                                  *
#  ****************************************************************
#  You can run SwiftComp for   0 days....
#
#  SwiftComp begins at  182049.951
#  Inputs echoed in file evals\sg.sg.ech!
#
#  Constitutive modeling for a 3D model!
#
#  Homogenization will be carried out!
#
#  You are running SwiftComp with full integration!
#
#  Finished reading/processing model file!
#
#  Effective properties can be found in file evals\sg.sg.k!
#
#  Finished homogenization!
#
#  SwiftComp ends at  182051.365
#  SwiftComp finished successfully!
#
#
# Running for radius: 0.2
# matrix_volumes=[17]
# inclusion_volumes=[19, 21, 18, 20]
#  ****************************************************************
#  *                      SwiftComp  2.1                          *
#  *                                                              *
#  *         Multiscale Constitutive Modeling of Composites       *
#  *                                                              *
#  *            School of Aeronautics and Astronautics            *
#  *                       Purdue University                      *
#  *                                                              *
#  *                       Copyright Notice                       *
#  *                     ====================                     *
#  *                                                              *
#  * Copyright (2015-) by Purdue Research Foundation, West        *
#  * Lafayette, IN  47906.  Unless permission is granted, this    *
#  * material may not be copied, reproduced or coded for          *
#  * reproduction by any electrical, mechanical or chemical       *
#  * process or combination thereof, now known or later developed.*
#  *                                                              *
#  * These commodities, technology or software were exported from *
#  * the United States in accordance with the Export              *
#  * Administration Regulations. Diversion contrary to U.S. law   *
#  * prohibited.                                                  *
#  ****************************************************************
#  You can run SwiftComp for   0 days....
#
#  SwiftComp begins at  182052.349
#  Inputs echoed in file evals\sg.sg.ech!
#
#  Constitutive modeling for a 3D model!
#
#  Homogenization will be carried out!
#
#  You are running SwiftComp with full integration!
#
#  Warning: there are a total of          374  aperiodic nodes out of total          553  nodes on y3 edge!
#  Finished reading/processing model file!
#
#  Effective properties can be found in file evals\sg.sg.k!
#
#  Finished homogenization!
#
#  SwiftComp ends at  182053.639
#  SwiftComp finished successfully!
#
#
# Running for radius: 0.30000000000000004
# matrix_volumes=[17]
# inclusion_volumes=[18, 21, 19, 20]
#  ****************************************************************
#  *                      SwiftComp  2.1                          *
#  *                                                              *
#  *         Multiscale Constitutive Modeling of Composites       *
#  *                                                              *
#  *            School of Aeronautics and Astronautics            *
#  *                       Purdue University                      *
#  *                                                              *
#  *                       Copyright Notice                       *
#  *                     ====================                     *
#  *                                                              *
#  * Copyright (2015-) by Purdue Research Foundation, West        *
#  * Lafayette, IN  47906.  Unless permission is granted, this    *
#  * material may not be copied, reproduced or coded for          *
#  * reproduction by any electrical, mechanical or chemical       *
#  * process or combination thereof, now known or later developed.*
#  *                                                              *
#  * These commodities, technology or software were exported from *
#  * the United States in accordance with the Export              *
#  * Administration Regulations. Diversion contrary to U.S. law   *
#  * prohibited.                                                  *
#  ****************************************************************
#  You can run SwiftComp for   0 days....
#
#  SwiftComp begins at  182054.638
#  Inputs echoed in file evals\sg.sg.ech!
#
#  Constitutive modeling for a 3D model!
#
#  Homogenization will be carried out!
#
#  You are running SwiftComp with full integration!
#
#  Warning: there are a total of          331  aperiodic nodes out of total          543  nodes on y3 edge!
#  Finished reading/processing model file!
#
#  Effective properties can be found in file evals\sg.sg.k!
#
#  Finished homogenization!
#
#  SwiftComp ends at  182055.896
#  SwiftComp finished successfully!
#
#
# Running for radius: 0.4
# matrix_volumes=[2]
# inclusion_volumes=[1, 6, 5, 3, 9, 4, 7, 8]
#  ****************************************************************
#  *                      SwiftComp  2.1                          *
#  *                                                              *
#  *         Multiscale Constitutive Modeling of Composites       *
#  *                                                              *
#  *            School of Aeronautics and Astronautics            *
#  *                       Purdue University                      *
#  *                                                              *
#  *                       Copyright Notice                       *
#  *                     ====================                     *
#  *                                                              *
#  * Copyright (2015-) by Purdue Research Foundation, West        *
#  * Lafayette, IN  47906.  Unless permission is granted, this    *
#  * material may not be copied, reproduced or coded for          *
#  * reproduction by any electrical, mechanical or chemical       *
#  * process or combination thereof, now known or later developed.*
#  *                                                              *
#  * These commodities, technology or software were exported from *
#  * the United States in accordance with the Export              *
#  * Administration Regulations. Diversion contrary to U.S. law   *
#  * prohibited.                                                  *
#  ****************************************************************
#  You can run SwiftComp for   0 days....
#
#  SwiftComp begins at  182057.047
#  Inputs echoed in file evals\sg.sg.ech!
#
#  Constitutive modeling for a 3D model!
#
#  Homogenization will be carried out!
#
#  You are running SwiftComp with full integration!
#
#  Warning: there are a total of          185  aperiodic nodes out of total          574  nodes on y3 edge!
#  Finished reading/processing model file!
#
#  Effective properties can be found in file evals\sg.sg.k!
#
#  Finished homogenization!
#
#  SwiftComp ends at  182058.579
#  SwiftComp finished successfully!

# %%
# out = sgio.readOutputModel(f'{fn_sg_sc}.k', file_format='sc', model_type='sd1')
# dict_out = out.model_dump(exclude_none=True)
# print(out)
# print(dict_out)
# Out:
# [{'radius': np.float64(0.1), 'fn_sg_sc': 'evals\\sg.sg', 'property': {'dim': 3, 'label': 'sd1', 'model_name': 'Cauchy continuum model', 'strain_name': ['e11', 'e22', 'e33', 'e23', 'e13', 'e12'], 'stress_name': ['s11', 's22', 's33', 's23', 's13', 's12'], 'name': '', 'isotropy': 2, 'density': 1005.914, 'temperature': 0, 'e1': 1009708600.0, 'e2': 1009671100.0, 'e3': 1009640900.0, 'g12': 388484770.0, 'g13': 388487710.0, 'g23': 388495410.0, 'nu12': 0.2994535, 'nu13': 0.29950212, 'nu23': 0.29941312, 'stff': [[1357169600.0, 580092630.0, 580130070.0, 2683.4674, 23905.3, 28709.143], [580092630.0, 1357044700.0, 580032160.0, -8297.4621, 898.66196, 7121.3501], [580130070.0, 580032160.0, 1357043500.0, 14885.168, 4041.2262, -3178.2319], [2683.4674, -8297.4621, 14885.168, 388495410.0, -4809.6375, -665.65982], [23905.3, 898.66196, 4041.2262, -4809.6375, 388487710.0, 2516.4782], [28709.143, 7121.3501, -3178.2319, -665.65982, 2516.4782, 388484770.0]], 'cmpl': [[9.9038475e-10, -2.9657418e-10, -2.9662233e-10, -1.8109009e-15, -5.7170505e-14, -7.0179536e-14], [-2.9657418e-10, 9.9042153e-10, -2.965452e-10, 3.4564243e-14, 1.9043613e-14, 1.3352845e-15], [-2.9662233e-10, -2.965452e-10, 9.9045114e-10, -4.2233607e-14, 8.6345336e-15, 3.5459328e-14], [-1.8109009e-15, 3.4564243e-14, -4.2233607e-14, 2.574033e-09, 3.1868028e-14, 4.4094952e-15], [-5.7170505e-14, 1.9043613e-14, 8.6345336e-15, 3.1868028e-14, 2.574084e-09, -1.667008e-14], [-7.0179536e-14, 1.3352845e-15, 3.5459328e-14, 4.4094952e-15, -1.667008e-14, 2.5741035e-09]], 'strength_measure': 0, 'char_len': 0, 'specific_heat': 0, 'failure_criterion': 0, 'd_thetatheta': 0, 'f_eff': 0}}, {'radius': np.float64(0.2), 'fn_sg_sc': 'evals\\sg.sg', 'property': {'dim': 3, 'label': 'sd1', 'model_name': 'Cauchy continuum model', 'strain_name': ['e11', 'e22', 'e33', 'e23', 'e13', 'e12'], 'stress_name': ['s11', 's22', 's33', 's23', 's13', 's12'], 'name': '', 'isotropy': 2, 'density': 1049.2807, 'temperature': 0, 'e1': 1077015000.0, 'e2': 1077042000.0, 'e3': 1076356000.0, 'g12': 412902680.0, 'g13': 412899460.0, 'g23': 412855690.0, 'nu12': 0.29589923, 'nu13': 0.29617949, 'nu23': 0.29593818, 'stff': [[1433815900.0, 602617110.0, 602630810.0, 16608.599, -7716.5076, 5296.7184], [602617110.0, 1433624000.0, 602367440.0, -56029.203, -32858.507, -6510.2365], [602630810.0, 602367440.0, 1432883600.0, -33518.597, 49494.121, 17761.016], [16608.599, -56029.203, -33518.597, 412855690.0, 15330.138, -26196.613], [-7716.5076, -32858.507, 49494.121, 15330.138, 412899470.0, 2508.9537], [5296.7184, -6510.2365, 17761.016, -26196.613, 2508.9537, 412902680.0]], 'cmpl': [[9.2849215e-10, -2.7474011e-10, -2.7500033e-10, -9.6965118e-14, 2.8456235e-14, -4.4197118e-15], [-2.7474011e-10, 9.2846887e-10, -2.7476939e-10, 1.1474654e-13, 1.0168505e-13, 2.9989408e-14], [-2.7500033e-10, -2.7476939e-10, 9.2906066e-10, 4.9203932e-14, -1.3837326e-13, -4.076418e-14], [-9.6965118e-14, 1.1474654e-13, 4.9203932e-14, 2.4221539e-09, -8.992928e-14, 1.5367505e-13], [2.8456235e-14, 1.0168505e-13, -1.3837326e-13, -8.992928e-14, 2.4218971e-09, -1.4714883e-14], [-4.4197118e-15, 2.9989408e-14, -4.076418e-14, 1.5367505e-13, -1.4714883e-14, 2.4218782e-09]], 'strength_measure': 0, 'char_len': 0, 'specific_heat': 0, 'failure_criterion': 0, 'd_thetatheta': 0, 'f_eff': 0}}, {'radius': np.float64(0.30000000000000004), 'fn_sg_sc': 'evals\\sg.sg', 'property': {'dim': 3, 'label': 'sd1', 'model_name': 'Cauchy continuum model', 'strain_name': ['e11', 'e22', 'e33', 'e23', 'e13', 'e12'], 'stress_name': ['s11', 's22', 's33', 's23', 's13', 's12'], 'name': '', 'isotropy': 2, 'density': 1168.061, 'temperature': 0, 'e1': 1302947200.0, 'e2': 1302884700.0, 'e3': 1300677500.0, 'g12': 479467920.0, 'g13': 478797360.0, 'g23': 478982440.0, 'nu12': 0.28309276, 'nu13': 0.28387987, 'nu23': 0.28379202, 'stff': [[1679359400.0, 663822270.0, 663974190.0, -45231.088, -8705.496, 21144.934], [663822270.0, 1679195000.0, 663852340.0, -89218.154, 65736.394, 68322.276], [663974190.0, 663852340.0, 1676914900.0,  ...

# %%
for _ in out:
    print(_)

eng_const_names = [
    'e1', 'e2', 'e3', 'nu12', 'nu13', 'nu23', 'g12', 'g13', 'g23'
    ]
eng_const_labels = [
    '$E_1$', '$E_2$', '$E_3$',
    '$\\nu_{12}$', '$\\nu_{13}$', '$\\nu_{23}$',
    '$G_{12}$', '$G_{13}$', '$G_{23}$'
    ]
props = []

for _ in out:
    prop = {'radius': _['radius']}
    for i, name in enumerate(eng_const_names):
        prop[name] = _['property'][name]
    props.append(prop)

df = pd.DataFrame(props)
print(df)
# Out:
# {'radius': np.float64(0.1), 'fn_sg_sc': 'evals\\sg.sg', 'property': {'dim': 3, 'label': 'sd1', 'model_name': 'Cauchy continuum model', 'strain_name': ['e11', 'e22', 'e33', 'e23', 'e13', 'e12'], 'stress_name': ['s11', 's22', 's33', 's23', 's13', 's12'], 'name': '', 'isotropy': 2, 'density': 1005.914, 'temperature': 0, 'e1': 1009708600.0, 'e2': 1009671100.0, 'e3': 1009640900.0, 'g12': 388484770.0, 'g13': 388487710.0, 'g23': 388495410.0, 'nu12': 0.2994535, 'nu13': 0.29950212, 'nu23': 0.29941312, 'stff': [[1357169600.0, 580092630.0, 580130070.0, 2683.4674, 23905.3, 28709.143], [580092630.0, 1357044700.0, 580032160.0, -8297.4621, 898.66196, 7121.3501], [580130070.
646714e-15, 7.816611e-14, -2.256345e-14], [-2.1570818e-14, 5.5793582e-14, 4.646714e-15, 1.5735854e-09, 1.3543739e-14, 3.9907406e-14], [-8.1103993e-14, -1.869657e-14, 7.816611e-14, 1.3543739e-14, 1.5755689e-09, 3.0246549e-14], [3.8948175e-14, -7.2838662e-14, -2.256345e-14, 3.9907406e-14, 3.0246549e-14, 1.5703817e-09]], 'strength_measure': 0, 'char_len': 0, 'specific_heat': 0, 'failure_criterion': 0, 'd_thetatheta': 0, 'f_eff': 0}}
#    radius            e1            e2            e3      nu12      nu13  \
# 0     0.1  1.009709e+09  1.009671e+09  1.009641e+09  0.299453  0.299502
# 1     0.2  1.077015e+09  1.077042e+09  1.076356e+09  0.295899  0.296179
# 2     0.3  1.302947e+09  1.302885e+09  1.300678e+09  0.283093  0.283880
# 3     0.4  2.028352e+09  2.030105e+09  2.029744e+09  0.244252  0.244005
#
#        nu23          g12          g13          g23
# 0  0.299413  388484770.0  388487710.0  388495410.0
# 1  0.295938  412902680.0  412899460.0  412855690.0
# 2  0.283792  479467920.0  478797360.0  478982440.0
# 3  0.243468  636787870.0  634691360.0  635491400.0

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create 3x3 subplot grid
fig = make_subplots(
    rows=3, cols=3,
    subplot_titles=eng_const_labels,
    shared_xaxes=True,
    shared_yaxes='rows',
    vertical_spacing=0.1,
    horizontal_spacing=0.05
)

# Plot each engineering constant
for i, const_name in enumerate(eng_const_names):
    row = i // 3 + 1
    col = i % 3 + 1
    
    fig.add_trace(
        go.Scatter(
            x=df['radius'],
            y=df[const_name],
            mode='lines+markers',
            name=eng_const_labels[i],
            showlegend=False
        ),
        row=row, col=col
    )

# Update layout
fig.update_layout(
    title="Engineering Constants vs Radius",
    height=600,
    width=800
)

# Update axes labels
fig.update_xaxes(title_text="Radius", row=3, col=1)
fig.update_xaxes(title_text="Radius", row=3, col=2)
fig.update_xaxes(title_text="Radius", row=3, col=3)

fig.update_yaxes(title_text="Young's Modulus (Pa)", row=1, col=1)
# fig.update_yaxes(title_text="Young's Modulus (Pa)", row=1, col=2)
# fig.update_yaxes(title_text="Young's Modulus (Pa)", row=1, col=3)

fig.update_yaxes(title_text="Poisson's Ratio", row=2, col=1)
# fig.update_yaxes(title_text="Poisson's Ratio", row=2, col=2)
# fig.update_yaxes(title_text="Poisson's Ratio", row=2, col=3)

fig.update_yaxes(title_text="Shear Modulus (Pa)", row=3, col=1)
# fig.update_yaxes(title_text="Shear Modulus (Pa)", row=3, col=2)
# fig.update_yaxes(title_text="Shear Modulus (Pa)", row=3, col=3)

# Enable LaTeX rendering by wrapping in MathJax delimiters
# Plotly automatically renders text between $ signs as LaTeX when displayed in Jupyter
fig.show()

# %%
# sg = sgio.read('sg.msh', file_format='gmsh')
# print(sg)

# print(sg.mesh.cells)
# print(sg.mesh.cell_sets)
# print(sg.mesh.cell_sets_dict)
# print(sg.mesh.cell_sets_to_data('set'))
# print(sg.mesh.cell_sets)

# %%
# if hasattr(sg.mesh, 'cell_sets') and sg.mesh.cell_sets:
#     sg.mesh.cell_sets.clear()

# mesh = pv.from_meshio(sg.mesh)
# print(mesh)

# %%
# pl = pv.Plotter()
# pl.add_mesh(mesh, color='w', show_edges=True)
# pl.show()
